# %% [markdown]
# ### 3.1 연산자의 종류

# %%
print(1 + 1)
# Out:
# 2

# %%
print(3 - 2)
# Out:
# 1

# %%
print(5 * 2)
# Out:
# 10

# %%
print(6 / 3)
# Out:
# 2.0

# %%
print(2**3) # 2^3 = 8
# Out:
# 8

# %%
print(5 % 3) # 나머지 구하기
# Out:
# 2

# %%
print(10 % 3)
# Out:
# 1

# %%
print(5 // 3)
# Out:
# 1

# %%
print(10 // 3)
# Out:
# 3

# %%
print(10 > 3)
# Out:
# True

# %%
print(4 >= 7)
# Out:
# False

# %%
print(10 < 3)
# Out:
# False

# %%
print(5 <= 5)
# Out:
# True

# %%
print(3 == 3)
# Out:
# True

# %%
print(4 == 2)
# Out:
# False

# %%
print(3 + 4 == 7)
# Out:
# True

# %%
print(1 != 3)
# Out:
# True

# %%
print(not(1 != 3))
# Out:
# False

# %%
print((3 > 0) and (3 < 5))
# Out:
# True

# %%
print((3 > 0) & (3 < 5))
# Out:
# True

# %%
print((3 > 0) or (3 > 5))
# Out:
# True

# %%
print((3 > 0) | (3 > 5))
# Out:
# True

# %%
print(5 > 4 > 3)
# Out:
# True

# %%
print(5 > 4 > 7)
# Out:
# False

# %% [markdown]
# ### 3.2 간단한 수식

# %%
print(2 + 3 * 4)
# Out:
# 14

# %%
print((2 + 3) * 4)
# Out:
# 20

# %%
number = 2 + 3 * 4
print(number)
# Out:
# 14

# %%
number = number + 2
print(number)
# Out:
# 16

# %%
number += 2
print(number)
# Out:
# 18

# %%
number *= 2
print(number)
# Out:
# 36

# %%
number /= 2
print(number)
# Out:
# 18.0

# %%
number -= 2
print(number)
# Out:
# 16.0

# %%
number %= 2
print(number)
# Out:
# 0.0

# %% [markdown]
# ### 3.3 숫자처리함수

# %%
print(abs(-5))
# Out:
# 5

# %%
print(pow(4, 2))
# Out:
# 16

# %%
print(max(5, 12))
# Out:
# 12

# %%
print(min(5, 12))
# Out:
# 5

# %%
print(round(3.14))
# Out:
# 3

# %%
print(round(4.99))
# Out:
# 5

# %%
from math import *
print(floor(4.99)) # 내림
# Out:
# 4

# %%
print(ceil(3.14)) # 올림
# Out:
# 4

# %%
print(sqrt(16)) # 제곱근
# Out:
# 4.0

# %% [markdown]
# ### 3.4 랜덤함수

# %%
from random import *

print(random()) # 0.0 ~ 1.0 미만의 임의의 값 생성
# Out:
# 0.5481681555860036

# %%
print(random() * 10) # 0.0 ~ 10.0 미만의 임의의 값 생섣ㅇ
# Out:
# 6.801982539983844

# %%
print(int(random() *  10)) # 0 ~ 10 미만의 임의의 값 생성
print(int(random() *  10)) # 0 ~ 10 미만의 임의의 값 생성
print(int(random() *  10)) # 0 ~ 10 미만의 임의의 값 생성
# Out:
# 1
# 7
# 8

# %%
print(int(random() * 10) + 1) # 1 ~ 10 이하의 임의의 값 생성
print(int(random() * 10) + 1) # 1 ~ 10 이하의 임의의 값 생성
print(int(random() * 10) + 1) # 1 ~ 10 이하의 임의의 값 생성
print(int(random() * 10) + 1) # 1 ~ 10 이하의 임의의 값 생성
print(int(random() * 10) + 1) # 1 ~ 10 이하의 임의의 값 생성
print(int(random() * 10) + 1) # 1 ~ 10 이하의 임의의 값 생성
# Out:
# 3
# 4
# 8
# 9
# 9
# 8

# %%
print(int(random() * 45) + 1) # 1 ~ 45 이하의 임의의 값 생성
print(int(random() * 45) + 1) # 1 ~ 45 이하의 임의의 값 생성
print(int(random() * 45) + 1) # 1 ~ 45 이하의 임의의 값 생성
print(int(random() * 45) + 1) # 1 ~ 45 이하의 임의의 값 생성
print(int(random() * 45) + 1) # 1 ~ 45 이하의 임의의 값 생성
print(int(random() * 45) + 1) # 1 ~ 45 이하의 임의의 값 생성
# Out:
# 11
# 6
# 45
# 23
# 5
# 20

# %%
print(randrange(1, 46)) # 1 ~ 46 미만의 임의의 값 생성
print(randrange(1, 46)) # 1 ~ 46 미만의 임의의 값 생성
print(randrange(1, 46)) # 1 ~ 46 미만의 임의의 값 생성
print(randrange(1, 46)) # 1 ~ 46 미만의 임의의 값 생성
print(randrange(1, 46)) # 1 ~ 46 미만의 임의의 값 생성
print(randrange(1, 46)) # 1 ~ 46 미만의 임의의 값 생성
# Out:
# 30
# 2
# 21
# 37
# 25
# 21

# %%
print(randint(1, 45)) # 1 ~ 45 이하의 임의의 값 생성
print(randint(1, 45)) # 1 ~ 45 이하의 임의의 값 생성
print(randint(1, 45)) # 1 ~ 45 이하의 임의의 값 생성
print(randint(1, 45)) # 1 ~ 45 이하의 임의의 값 생성
print(randint(1, 45)) # 1 ~ 45 이하의 임의의 값 생성
print(randint(1, 45)) # 1 ~ 45 이하의 임의의 값 생성
# Out:
# 22
# 16
# 30
# 28
# 26
# 45

# %% [markdown]
# ### 퀴즈 # 2

# %%
# Quiz) 당신은 최근에 코딩 스터디 모임을 새로 만들었습니다.
# 월 4회 스터디를 하는데 3번은 온라인으로 하고 1번은 오프라인으로 하기로 했습니다.
# 아래 조건에 맞는 오프라인 모임 날짜를 정해주는 프로그램을 작성하시오.

# 조건1 : 랜덤으로 날짜를 뽑아야 함
# 조건2 : 월별 날짜는 다름을 감안하여 최소 일수인 28 이내로 정함
# 조건3 : 매월 1~3일은 스터디 준비를 해야 하므로 제외

# (출력문 예제)
# 오프라인 스터디 모임 날짜는 매월 x 일로 선정되었습니다.

from random import *

date = randint(4, 28)
print("오프라인 스터디 모임 날짜는 매월 " + str(date) + "일로 선정되었습니다.")
# Out:
# 오프라인 스터디 모임 날짜는 매월 28일로 선정되었습니다.
